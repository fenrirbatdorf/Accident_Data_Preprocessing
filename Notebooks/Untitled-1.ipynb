# %%
import pandas as pd
import numpy as np

# %%
df0 = pd.read_csv("../Accident_Data_Preprocessing/census0_binned.csv")
df1 = pd.read_csv("../Accident_Data_Preprocessing/census1_binned.csv")
df = pd.concat([df0, df1], axis = 0)
df
# Out:
#                      age     type_employer                     fnlwgt  \
# 0      '\'(39.5-45.5]\''  Self-emp-not-inc    '\'(138590-176261.5]\''
# 1      '\'(34.5-39.5]\''           Private    '\'(138590-176261.5]\''
# 2      '\'(45.5-52.5]\''           Private       '\'(96945-138590]\''
# 3      '\'(-inf-27.5]\''           Private  '\'(176261.5-206692.5]\''
# 4      '\'(45.5-52.5]\''         State-gov       '\'(276793.5-inf)\''
# ...                  ...               ...                        ...
# 37247  '\'(39.5-45.5]\''           Private    '\'(138590-176261.5]\''
# 37248  '\'(45.5-52.5]\''       Federal-gov         '\'(-inf-96945]\''
# 37249  '\'(45.5-52.5]\''           Private    '\'(138590-176261.5]\''
# 37250  '\'(45.5-52.5]\''           Private       '\'(276793.5-inf)\''
# 37251  '\'(39.5-45.5]\''           Private       '\'(96945-138590]\''
#
#        education_num      marital_status         occupation   relationship  \
# ...

# %%
for i in df.columns:
    print(df[i].name, df[i].nunique())
# Out:
# age 6
# type_employer 7
# fnlwgt 6
# education_num 16
# marital_status 7
# occupation 14
# relationship 6
# race 5
# sex 2
# hr_worked_per_week 6
