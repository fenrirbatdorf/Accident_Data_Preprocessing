# %% [markdown]
# This notebook is a "quick fix" notebook that simply copies the feature engineer notebook, and gives space to try creating and analyzing various new columns (Currently being used to examine if severity is directly linked to the length of time an accident was recorded).

# %%
# Imports
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
import numpy as np

# %%
# Train data needs Data_Raw, train_data, X_train, y_train
# Test data needs Data_Raw, test_data, X_test, y_test
def data_input(folder1, folder2, file_x, file_y):
    X = pd.read_csv(f"../Accident_Data_Preprocessing/{folder1}/{folder2}/{file_x}.csv")
    y = pd.read_csv(f"../Accident_Data_Preprocessing/{folder1}/{folder2}/{file_y}.csv")
    df = pd.concat([X, y], axis=1)
    return df

# %%
# TRAIN INPUT


#df = data_input("Data_Raw", "train_data", "X_train", "y_train")
df = pd.read_csv("C:\\Users\\bkb3\\Accident_Data_Preprocessing\\Data_Raw\\full_data\\mdtraffic.csv")
df.head()
# Out:
#          ID   Source  Severity           Start_Time             End_Time  \
# 0  A-228553  Source2         2  2016-11-30 11:58:01  2016-11-30 16:57:20
# 1  A-228554  Source2         3  2016-11-30 12:04:03  2016-11-30 17:02:36
# 2  A-228567  Source2         2  2016-11-30 16:54:53  2016-11-30 17:24:12
# 3  A-228574  Source2         2  2016-11-30 17:33:47  2016-11-30 18:01:49
# 4  A-228580  Source2         2  2016-11-30 17:35:33  2016-11-30 18:05:10
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.152046 -76.645584      NaN      NaN          0.01  ...      False
# 1  39.152046 -76.645584      NaN      NaN          0.01  ...      False
# 2  39.481083 -76.249626      NaN      NaN          0.01  ...      False
# 3  39.158756 -76.718475      NaN      NaN          0.01  ...      False
# 4  39.636391 -77.710457      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False            Day
# 1   False  False           False          False        False            Day
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False          Night
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2            Day               Day                   Day
# 3          Night               Day                   Day
# 4          Night               Day                   Day
#
# [5 rows x 46 columns]

# %%
# TEST INPUT
#df = data_input("Data_Raw", "test_data", "X_test", "y_test")
#df.head()
# Out:
#           ID   Source                     Start_Time  \
# 0   A-237917  Source2            2016-10-23 08:04:38
# 1  A-5361038  Source1  2022-03-10 17:06:30.000000000
# 2  A-4110445  Source1            2022-09-19 04:45:21
# 3  A-1228048  Source2            2020-12-15 08:03:36
# 4  A-1450465  Source2            2020-05-28 08:21:25
#
#                         End_Time  Start_Lat  Start_Lng    End_Lat    End_Lng  \
# 0            2016-10-23 09:04:14  39.011890 -76.904198        NaN        NaN
# 1  2022-03-10 17:28:30.000000000  38.599807 -75.913079  38.606758 -75.902799
# 2            2022-09-19 06:01:06  38.930465 -76.013555  38.931595 -76.019579
# 3            2020-12-15 09:18:22  39.562180 -76.361221        NaN        NaN
# 4            2020-05-28 09:05:57  39.277962 -77.323425        NaN        NaN
#
#    Distance(mi)                                        Description  ...  \
# 0         0.010  Accident on I-95 Capital Beltway Southbound at...  ...
# 1         0.734  Stationary traffic on MD-392 from MD-14/E New ...  ...
# 2         0.333  Incident on MD-404 WB near DULIN RD Drive with...  ...
# 3         0.000            Accident on Kahoe Rd at Bynum Ridge Rd.  ...
# 4         0.000  Accident on I-270 Northbound before Exit 22 MD...  ...
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False            Day
# 1   False  False           False          False        False            Day
# 2   False  False           False          False        False          Night
# 3   False  False           False          False        False            Day
# 4   False  False           False          False        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight  Severity
# 0            Day               Day                   Day         3
# 1            Day               Day                   Day         2
# 2          Night             Night                 Night         2
# 3            Day               Day                   Day         2
# 4            Day               Day                   Day         2
#
# [5 rows x 46 columns]

# %%
# View data, remove duplicate rows
df.head()
df = df.drop_duplicates()

# %%
# Check all unique values for all columns
for col in df.columns:
    print(df[col].value_counts(sort=True))
# Out:
# ID
# A-5887205    1
# A-237917     1
# A-5361038    1
# A-4110445    1
# A-1228048    1
#             ..
# A-6985967    1
# A-4223854    1
# A-1495843    1
# A-5332319    1
# A-1337540    1
# Name: count, Length: 28084, dtype: int64
# Source
# Source1    19701
# Source2     8250
# Source3      133
# Name: count, dtype: int64
# Start_Time
# 2021-05-28 07:31:48              8
# 2020-11-16 15:24:21              5
# 2021-10-17 19:13:00              5
# 2021-01-27 16:33:28              5
# 2020-12-17 06:26:18              5
#                                 ..
# 2022-11-08 17:49:00.000000000    1
# 2021-04-24 04:49:00              1
# 2022-11-17 17:07:10              1
# 2017-06-17 14:38:33              1
# 2022-06-08 14:51:27              1
# Name: count, Length: 26867, dtype: int64
# End_Time
# 2021-07-28 19:18:21              4
# 2022-08-24 21:05:53              4
# 2022-07-24 16:05:56              3
# 2018-02-17 00:44:51              3
# 2020-10-29 16:05:16              3
#                                 ..
# 2022-02-24 09:14:51              1
# 2022-10-08 08:27:46.000000000    1
# 2021-01-31 09:37:01              1
# 2020-10-02 03:39:30              1
# 2020-11-21 03:10:47              1
# Name: count, Length: 27420, dtype: int64
# Start_Lat
# 38.971164    45
# 39.442020    40
# 39.379276    40
# 39.442108    35
# 39.382286    33
#              ..
# 39.671962     1
# 39.004311     1
# 39.201089     1
# 39.299600     1
# 39.248256     1
# Name: count, Length: 17259, dtype: int64
# Start_Lng
# -77.179063    45
# -76.349358    40
# -76.448280    39
# -76.348763    34
# -76.679230    33
#               ..
# -76.901306     1
# -77.074668     1
# -76.692322     1
# -76.717369     1
# -76.922158     1
# Name: count, Length: 17309, dtype: int64
# End_Lat
# 38.912285    23
# 39.466545    22
# 38.988969    22
# 39.019136    18
# 39.019034    16
#              ..
# 39.329630     1
# 39.405863     1
# 39.382457     1
# 38.980048     1
# 39.145372     1
# Name: count, Length: 13005, dtype: int64
# End_Lng
# -76.934168    23
# -76.987615    22
# -76.286576    22
# -76.959084    18
# -77.388047    16
#               ..
# -75.846650     1
# -76.858240     1
# -76.900852     1
# -75.819471     1
# -76.933413     1
# Name: count, Length: 13042, dtype: int64
# Distance(mi)
# 0.000    7627
# 0.010    1299
# 0.010      76
# 0.020      65
# 0.028      63
#          ...
# 1.540       1
# 0.220       1
# 2.955       1
# 2.045       1
# 2.439       1
# Name: count, Length: 3601, dtype: int64
# Description
# Incident on BRANCH AVE near BRANCH AVE Drive with caution.                                                103
# Incident on CRAIN HWY near CRAIN HWY Drive with caution.                                                   90
# Incident on I-495 WB near I-495 Drive with caution.                                                        85
# Incident on I-495 EB near I-495 Drive with caution.                                                        77
# Incident on INDIAN HEAD HWY near INDIAN HEAD HWY Drive with caution.                                       66
#                                                                                                          ...
# MD 28 EAST/WEST AT PLEASANTVIEW RD                                                                          1
# I-695 OUTER LOOP AT EXIT 15B US 40 BALTO NATIONAL PIKE (OL)                                                 1
# Right lane blocked and right hand shoulder blocked due to accident on I-795 Northbound at McDongh Rd .      1
# Accident on I-495 Capital Beltway anticlockwise at Exits 25B-A 27 I-95.                                     1
# Accident on Terps Blvd at Nittany Lion Cir.                                                                 1
# Name: count, Length: 20390, dtype: int64
# Street
# I-95 S                1171
# I-95 N                1119
# Capital Beltway S      814
# Capital Beltway N      616
# I-695 E                554
#                       ...
# Foxlake Dr               1
# Walnut Ave               1
# Devonshire Ln            1
# Hudson Rd                1
# Piney Orchard Pkwy       1
# Name: count, Length: 3480, dtype: int64
# City
# Baltimore               1910
# Frederick               1625
# Silver Spring           1599
# Hyattsville             1144
# Bethesda                1004
#                         ...
# Great Mills                1
# Kitzmiller                 1
# District 24 Braddock       1
# Rawlings                   1
# District 2                 1
# Name: count, Length: 338, dtype: int64
# County
# Prince George's         5365
# Montgomery              4494
# Baltimore County        3673
# Frederick               2634
# Anne Arundel            2405
# Baltimore City          1761
# Harford                 1349
# Howard                  1169
# Washington               950
# Baltimore                851
# Cecil                    485
# Queen Anne's             409
# Charles                  392
# Baltimore (City)         324
# Carroll                  261
# Worcester                236
# Talbot                   235
# Caroline                 175
# Allegany                 152
# Wicomico                 127
# Dorchester               116
# St. Mary's               111
# Queen Annes               97
# Kent                      70
# Garrett                   69
# Prince Georges            58
# Calvert                   47
# Somerset                  45
# St Marys                  23
# District Of Columbia       1
# Name: count, dtype: int64
# State
# MD    28084
# Name: count, dtype: int64
# Zipcode
# 21227         640
# 21224         631
# 20817         519
# 21704         446
# 21208         428
#              ...
# 20623-1153      1
# 20794-9308      1
# 21561-1437      1
# 21842-3758      1
# 21152-9121      1
# Name: count, Length: 3791, dtype: int64
# Country
# US    28084
# Name: count, dtype: int64
# Timezone
# US/Eastern    28033
# Name: count, dtype: int64
# Airport_Code
# KCGS    4832
# KDMH    4343
# KFDK    2373
# KBWI    2337
# KMTN    1734
# KGAI    1692
# KAPG    1385
# KDCA    1266
# KFME    1219
# KADW    1142
# KWBC     968
# KHGR     729
# KNAK     665
# KDMW     599
# KRSP     402
# KRJD     330
# KW29     297
# KOXB     200
# KESN     197
# KCGE     178
# KILG     171
# KCBE     157
# KDAA     151
# KSBY     150
# K2W6     143
# KMRB     109
# K2G4      64
# KWAL      48
# KJYO      43
# KNHK      32
# KNYG      30
# KRYT      30
# KNUI       3
# Name: count, dtype: int64
# Weather_Timestamp
# 2021-05-28 07:58:00    9
# 2022-03-13 01:55:00    9
# 2022-05-31 07:39:00    8
# 2020-06-04 07:54:00    8
# 2022-01-03 10:47:00    7
#                       ..
# 2022-08-11 21:55:00    1
# 2022-08-23 09:52:00    1
# 2021-04-24 04:56:00    1
# 2018-03-13 07:54:00    1
# 2022-03-21 16:54:00    1
# Name: count, Length: 21261, dtype: int64
# Temperature(F)
# 32.0    540
# 50.0    526
# 45.0    506
# 73.0    502
# 43.0    502
#        ...
# 1.0       1
# 16.9      1
# 60.6      1
# 93.7      1
# 99.0      1
# Name: count, Length: 442, dtype: int64
# Wind_Chill(F)
#  70.0    419
#  72.0    413
#  73.0    408
#  54.0    376
#  50.0    374
#         ...
# -14.5      1
#  1.1       1
#  20.1      1
#  9.9       1
#  5.2       1
# Name: count, Length: 388, dtype: int64
# Humidity(%)
# 100.0    1767
# 93.0     1302
# 94.0     1013
# 87.0      517
# 88.0      436
#          ...
# 11.0        8
# 14.0        7
# 12.0        3
# 10.0        1
# 9.0         1
# Name: count, Length: 92, dtype: int64
# Pressure(in)
# 30.06    439
# 29.94    433
# 30.01    427
# 30.04    418
# 29.99    412
#         ...
# 26.94      1
# 28.82      1
# 27.15      1
# 26.75      1
# 28.76      1
# Name: count, Length: 236, dtype: int64
# Visibility(mi)
# 10.00    17732
# 7.00      1134
# 5.00       557
# 3.00       460
# 4.00       455
# 2.00       408
# 1.00       391
# 9.00       357
# 8.00       260
# 6.00       258
# 0.50       114
# 0.25        89
# 2.50        69
# 0.75        56
# 0.20        38
# 1.50        35
# 1.80        27
# 0.80        21
# 1.20        17
# 0.12         9
# 0.00         9
# 0.38         7
# 0.19         7
# 0.10         4
# 0.63         4
# 0.06         2
# 20.00        2
# 2.80         1
# 0.60         1
# 0.88         1
# 1.90         1
# 10.50        1
# Name: count, dtype: int64
# Wind_Direction
# CALM        4497
# WNW         1639
# NW          1576
# North       1573
# Calm        1494
# W           1298
# S           1240
# NNW         1120
# SSW         1070
# N            915
# SW           870
# SSE          766
# SE           748
# NNE          734
# WSW          726
# NE           641
# ENE          578
# E            568
# ESE          484
# West         402
# VAR          397
# South        291
# East         223
# Variable     155
# Name: count, dtype: int64
# Wind_Speed(mph)
# 0.0      4497
# 6.0      1792
# 5.0      1761
# 3.0      1730
# 7.0      1546
# 8.0      1192
# 9.0      1101
# 10.0      918
# 12.0      743
# 3.5       573
# 13.0      522
# 5.8       512
# 4.6       511
# 6.9       449
# 14.0      411
# 15.0      405
# 8.1       345
# 9.2       293
# 10.4      264
# 11.5      216
# 16.0      207
# 17.0      166
# 12.7      126
# 13.8      126
# 18.0      118
# 20.0       99
# 17.3       80
# 21.0       71
# 16.1       69
# 23.0       50
# 18.4       43
# 22.0       40
# 19.6       35
# 20.7       22
# 21.9       21
# 24.0       20
# 25.0       19
# 24.2        9
# 25.3        8
# 2.3         5
# 29.0        5
# 26.5        5
# 30.0        5
# 26.0        5
# 31.0        4
# 28.8        4
# 28.0        3
# 32.0        3
# 38.0        3
# 27.6        2
# 32.2        1
# 31.1        1
# 126.6       1
# 33.0        1
# 33.4        1
# 1.0         1
# Name: count, dtype: int64
# Precipitation(in)
# 0.00    16772
# 0.01      388
# 0.02      220
# 0.03      136
# 0.04      100
#         ...
# 1.37        1
# 0.49        1
# 0.83        1
# 0.40        1
# 0.61        1
# Name: count, Length: 61, dtype: int64
# Weather_Condition
# Fair                    7770
# Cloudy                  3608
# Mostly Cloudy           2886
# Partly Cloudy           1938
# Clear                   1898
#                         ...
# Light Freezing Fog         2
# Sand                       1
# Light Sleet / Windy        1
# Light Snow and Sleet       1
# Wintry Mix / Windy         1
# Name: count, Length: 61, dtype: int64
# Amenity
# False    27887
# True       197
# Name: count, dtype: int64
# Bump
# False    28080
# True         4
# Name: count, dtype: int64
# Crossing
# False    26272
# True      1812
# Name: count, dtype: int64
# Give_Way
# False    28009
# True        75
# Name: count, dtype: int64
# Junction
# False    24638
# True      3446
# Name: count, dtype: int64
# No_Exit
# False    28045
# True        39
# Name: count, dtype: int64
# Railway
# False    27966
# True       118
# Name: count, dtype: int64
# Roundabout
# False    28083
# True         1
# Name: count, dtype: int64
# Station
# False    27579
# True       505
# Name: count, dtype: int64
# Stop
# False    27789
# True       295
# Name: count, dtype: int64
# Traffic_Calming
# False    27980
# True       104
# Name: count, dtype: int64
# Traffic_Signal
# False    24880
# True      3204
# Name: count, dtype: int64
# Turning_Loop
# False    28084
# Name: count, dtype: int64
# Sunrise_Sunset
# Day      18715
# Night     9315
# Name: count, dtype: int64
# Civil_Twilight
# Day      20084
# Night     7946
# Name: count, dtype: int64
# Nautical_Twilight
# Day      21476
# Night     6554
# Name: count, dtype: int64
# Astronomical_Twilight
# Day      22676
# Night     5354
# Name: count, dtype: int64
# Severity
# 2    20712
# 3     5090
# 4     2179
# 1      103
# Name: count, dtype: int64

# %%
# Worth keeping weather time stamp? Examine value types
print(df["Weather_Timestamp"].value_counts(sort=True))
# Out:
# Weather_Timestamp
# 2021-05-28 07:58:00    9
# 2022-03-13 01:55:00    9
# 2022-05-31 07:39:00    8
# 2020-06-04 07:54:00    8
# 2022-01-03 10:47:00    7
#                       ..
# 2022-08-11 21:55:00    1
# 2022-08-23 09:52:00    1
# 2021-04-24 04:56:00    1
# 2018-03-13 07:54:00    1
# 2022-03-21 16:54:00    1
# Name: count, Length: 21261, dtype: int64

# %%
# Check all values of all remaining cols
for col in df.columns:
    print(df[col].value_counts(sort=True))
# Out:
# ID
# A-5887205    1
# A-237917     1
# A-5361038    1
# A-4110445    1
# A-1228048    1
#             ..
# A-6985967    1
# A-4223854    1
# A-1495843    1
# A-5332319    1
# A-1337540    1
# Name: count, Length: 28084, dtype: int64
# Source
# Source1    19701
# Source2     8250
# Source3      133
# Name: count, dtype: int64
# Start_Time
# 2021-05-28 07:31:48              8
# 2020-11-16 15:24:21              5
# 2021-10-17 19:13:00              5
# 2021-01-27 16:33:28              5
# 2020-12-17 06:26:18              5
#                                 ..
# 2022-11-08 17:49:00.000000000    1
# 2021-04-24 04:49:00              1
# 2022-11-17 17:07:10              1
# 2017-06-17 14:38:33              1
# 2022-06-08 14:51:27              1
# Name: count, Length: 26867, dtype: int64
# End_Time
# 2021-07-28 19:18:21              4
# 2022-08-24 21:05:53              4
# 2022-07-24 16:05:56              3
# 2018-02-17 00:44:51              3
# 2020-10-29 16:05:16              3
#                                 ..
# 2022-02-24 09:14:51              1
# 2022-10-08 08:27:46.000000000    1
# 2021-01-31 09:37:01              1
# 2020-10-02 03:39:30              1
# 2020-11-21 03:10:47              1
# Name: count, Length: 27420, dtype: int64
# Start_Lat
# 38.971164    45
# 39.442020    40
# 39.379276    40
# 39.442108    35
# 39.382286    33
#              ..
# 39.671962     1
# 39.004311     1
# 39.201089     1
# 39.299600     1
# 39.248256     1
# Name: count, Length: 17259, dtype: int64
# Start_Lng
# -77.179063    45
# -76.349358    40
# -76.448280    39
# -76.348763    34
# -76.679230    33
#               ..
# -76.901306     1
# -77.074668     1
# -76.692322     1
# -76.717369     1
# -76.922158     1
# Name: count, Length: 17309, dtype: int64
# End_Lat
# 38.912285    23
# 39.466545    22
# 38.988969    22
# 39.019136    18
# 39.019034    16
#              ..
# 39.329630     1
# 39.405863     1
# 39.382457     1
# 38.980048     1
# 39.145372     1
# Name: count, Length: 13005, dtype: int64
# End_Lng
# -76.934168    23
# -76.987615    22
# -76.286576    22
# -76.959084    18
# -77.388047    16
#               ..
# -75.846650     1
# -76.858240     1
# -76.900852     1
# -75.819471     1
# -76.933413     1
# Name: count, Length: 13042, dtype: int64
# Distance(mi)
# 0.000    7627
# 0.010    1299
# 0.010      76
# 0.020      65
# 0.028      63
#          ...
# 1.540       1
# 0.220       1
# 2.955       1
# 2.045       1
# 2.439       1
# Name: count, Length: 3601, dtype: int64
# Description
# Incident on BRANCH AVE near BRANCH AVE Drive with caution.                                                103
# Incident on CRAIN HWY near CRAIN HWY Drive with caution.                                                   90
# Incident on I-495 WB near I-495 Drive with caution.                                                        85
# Incident on I-495 EB near I-495 Drive with caution.                                                        77
# Incident on INDIAN HEAD HWY near INDIAN HEAD HWY Drive with caution.                                       66
#                                                                                                          ...
# MD 28 EAST/WEST AT PLEASANTVIEW RD                                                                          1
# I-695 OUTER LOOP AT EXIT 15B US 40 BALTO NATIONAL PIKE (OL)                                                 1
# Right lane blocked and right hand shoulder blocked due to accident on I-795 Northbound at McDongh Rd .      1
# Accident on I-495 Capital Beltway anticlockwise at Exits 25B-A 27 I-95.                                     1
# Accident on Terps Blvd at Nittany Lion Cir.                                                                 1
# Name: count, Length: 20390, dtype: int64
# Street
# I-95 S                1171
# I-95 N                1119
# Capital Beltway S      814
# Capital Beltway N      616
# I-695 E                554
#                       ...
# Foxlake Dr               1
# Walnut Ave               1
# Devonshire Ln            1
# Hudson Rd                1
# Piney Orchard Pkwy       1
# Name: count, Length: 3480, dtype: int64
# City
# Baltimore               1910
# Frederick               1625
# Silver Spring           1599
# Hyattsville             1144
# Bethesda                1004
#                         ...
# Great Mills                1
# Kitzmiller                 1
# District 24 Braddock       1
# Rawlings                   1
# District 2                 1
# Name: count, Length: 338, dtype: int64
# County
# Prince George's         5365
# Montgomery              4494
# Baltimore County        3673
# Frederick               2634
# Anne Arundel            2405
# Baltimore City          1761
# Harford                 1349
# Howard                  1169
# Washington               950
# Baltimore                851
# Cecil                    485
# Queen Anne's             409
# Charles                  392
# Baltimore (City)         324
# Carroll                  261
# Worcester                236
# Talbot                   235
# Caroline                 175
# Allegany                 152
# Wicomico                 127
# Dorchester               116
# St. Mary's               111
# Queen Annes               97
# Kent                      70
# Garrett                   69
# Prince Georges            58
# Calvert                   47
# Somerset                  45
# St Marys                  23
# District Of Columbia       1
# Name: count, dtype: int64
# State
# MD    28084
# Name: count, dtype: int64
# Zipcode
# 21227         640
# 21224         631
# 20817         519
# 21704         446
# 21208         428
#              ...
# 20623-1153      1
# 20794-9308      1
# 21561-1437      1
# 21842-3758      1
# 21152-9121      1
# Name: count, Length: 3791, dtype: int64
# Country
# US    28084
# Name: count, dtype: int64
# Timezone
# US/Eastern    28033
# Name: count, dtype: int64
# Airport_Code
# KCGS    4832
# KDMH    4343
# KFDK    2373
# KBWI    2337
# KMTN    1734
# KGAI    1692
# KAPG    1385
# KDCA    1266
# KFME    1219
# KADW    1142
# KWBC     968
# KHGR     729
# KNAK     665
# KDMW     599
# KRSP     402
# KRJD     330
# KW29     297
# KOXB     200
# KESN     197
# KCGE     178
# KILG     171
# KCBE     157
# KDAA     151
# KSBY     150
# K2W6     143
# KMRB     109
# K2G4      64
# KWAL      48
# KJYO      43
# KNHK      32
# KNYG      30
# KRYT      30
# KNUI       3
# Name: count, dtype: int64
# Weather_Timestamp
# 2021-05-28 07:58:00    9
# 2022-03-13 01:55:00    9
# 2022-05-31 07:39:00    8
# 2020-06-04 07:54:00    8
# 2022-01-03 10:47:00    7
#                       ..
# 2022-08-11 21:55:00    1
# 2022-08-23 09:52:00    1
# 2021-04-24 04:56:00    1
# 2018-03-13 07:54:00    1
# 2022-03-21 16:54:00    1
# Name: count, Length: 21261, dtype: int64
# Temperature(F)
# 32.0    540
# 50.0    526
# 45.0    506
# 73.0    502
# 43.0    502
#        ...
# 1.0       1
# 16.9      1
# 60.6      1
# 93.7      1
# 99.0      1
# Name: count, Length: 442, dtype: int64
# Wind_Chill(F)
#  70.0    419
#  72.0    413
#  73.0    408
#  54.0    376
#  50.0    374
#         ...
# -14.5      1
#  1.1       1
#  20.1      1
#  9.9       1
#  5.2       1
# Name: count, Length: 388, dtype: int64
# Humidity(%)
# 100.0    1767
# 93.0     1302
# 94.0     1013
# 87.0      517
# 88.0      436
#          ...
# 11.0        8
# 14.0        7
# 12.0        3
# 10.0        1
# 9.0         1
# Name: count, Length: 92, dtype: int64
# Pressure(in)
# 30.06    439
# 29.94    433
# 30.01    427
# 30.04    418
# 29.99    412
#         ...
# 26.94      1
# 28.82      1
# 27.15      1
# 26.75      1
# 28.76      1
# Name: count, Length: 236, dtype: int64
# Visibility(mi)
# 10.00    17732
# 7.00      1134
# 5.00       557
# 3.00       460
# 4.00       455
# 2.00       408
# 1.00       391
# 9.00       357
# 8.00       260
# 6.00       258
# 0.50       114
# 0.25        89
# 2.50        69
# 0.75        56
# 0.20        38
# 1.50        35
# 1.80        27
# 0.80        21
# 1.20        17
# 0.12         9
# 0.00         9
# 0.38         7
# 0.19         7
# 0.10         4
# 0.63         4
# 0.06         2
# 20.00        2
# 2.80         1
# 0.60         1
# 0.88         1
# 1.90         1
# 10.50        1
# Name: count, dtype: int64
# Wind_Direction
# CALM        4497
# WNW         1639
# NW          1576
# North       1573
# Calm        1494
# W           1298
# S           1240
# NNW         1120
# SSW         1070
# N            915
# SW           870
# SSE          766
# SE           748
# NNE          734
# WSW          726
# NE           641
# ENE          578
# E            568
# ESE          484
# West         402
# VAR          397
# South        291
# East         223
# Variable     155
# Name: count, dtype: int64
# Wind_Speed(mph)
# 0.0      4497
# 6.0      1792
# 5.0      1761
# 3.0      1730
# 7.0      1546
# 8.0      1192
# 9.0      1101
# 10.0      918
# 12.0      743
# 3.5       573
# 13.0      522
# 5.8       512
# 4.6       511
# 6.9       449
# 14.0      411
# 15.0      405
# 8.1       345
# 9.2       293
# 10.4      264
# 11.5      216
# 16.0      207
# 17.0      166
# 12.7      126
# 13.8      126
# 18.0      118
# 20.0       99
# 17.3       80
# 21.0       71
# 16.1       69
# 23.0       50
# 18.4       43
# 22.0       40
# 19.6       35
# 20.7       22
# 21.9       21
# 24.0       20
# 25.0       19
# 24.2        9
# 25.3        8
# 2.3         5
# 29.0        5
# 26.5        5
# 30.0        5
# 26.0        5
# 31.0        4
# 28.8        4
# 28.0        3
# 32.0        3
# 38.0        3
# 27.6        2
# 32.2        1
# 31.1        1
# 126.6       1
# 33.0        1
# 33.4        1
# 1.0         1
# Name: count, dtype: int64
# Precipitation(in)
# 0.00    16772
# 0.01      388
# 0.02      220
# 0.03      136
# 0.04      100
#         ...
# 1.37        1
# 0.49        1
# 0.83        1
# 0.40        1
# 0.61        1
# Name: count, Length: 61, dtype: int64
# Weather_Condition
# Fair                    7770
# Cloudy                  3608
# Mostly Cloudy           2886
# Partly Cloudy           1938
# Clear                   1898
#                         ...
# Light Freezing Fog         2
# Sand                       1
# Light Sleet / Windy        1
# Light Snow and Sleet       1
# Wintry Mix / Windy         1
# Name: count, Length: 61, dtype: int64
# Amenity
# False    27887
# True       197
# Name: count, dtype: int64
# Bump
# False    28080
# True         4
# Name: count, dtype: int64
# Crossing
# False    26272
# True      1812
# Name: count, dtype: int64
# Give_Way
# False    28009
# True        75
# Name: count, dtype: int64
# Junction
# False    24638
# True      3446
# Name: count, dtype: int64
# No_Exit
# False    28045
# True        39
# Name: count, dtype: int64
# Railway
# False    27966
# True       118
# Name: count, dtype: int64
# Roundabout
# False    28083
# True         1
# Name: count, dtype: int64
# Station
# False    27579
# True       505
# Name: count, dtype: int64
# Stop
# False    27789
# True       295
# Name: count, dtype: int64
# Traffic_Calming
# False    27980
# True       104
# Name: count, dtype: int64
# Traffic_Signal
# False    24880
# True      3204
# Name: count, dtype: int64
# Turning_Loop
# False    28084
# Name: count, dtype: int64
# Sunrise_Sunset
# Day      18715
# Night     9315
# Name: count, dtype: int64
# Civil_Twilight
# Day      20084
# Night     7946
# Name: count, dtype: int64
# Nautical_Twilight
# Day      21476
# Night     6554
# Name: count, dtype: int64
# Astronomical_Twilight
# Day      22676
# Night     5354
# Name: count, dtype: int64
# Severity
# 2    20712
# 3     5090
# 4     2179
# 1      103
# Name: count, dtype: int64

# %%
# Date/time conversion of start and end time
df['Start_Time'] = pd.to_datetime(df['Start_Time'],format='mixed')
df['End_Time'] = pd.to_datetime(df['End_Time'], format = 'mixed')
df['Year'], df['Month'], df['Day'] = df['Start_Time'].dt.year, df['Start_Time'].dt.month, df['Start_Time'].dt.day

df['Accident_Time'] = df['End_Time']-df['Start_Time']
df4 = df[df['Severity']==4]
df123 = df[df['Severity'] !=4]
df4
df123
df4 = df4.dropna(how='any')
df123 = df123.dropna(how='any')

df4['Accident_Time'].idxmax()
df123['Accident_Time'].idxmax()
df4
df4["Accident_Time"].describe()
df123['Accident_Time'].describe()
df123['Accident_Time'].idxmax()

df4 = df4[df4['Accident_Time'] < "24 hours 47 minutes" ]
print(df4['Accident_Time'].describe())
df123 = df123[df123["Accident_Time"] < "1 day 11 minutes"]
print(df123['Accident_Time'].describe())
# Out:
# count                         5345
# mean     0 days 01:53:52.438353601
# std      0 days 01:33:10.416995883
# min                0 days 00:12:24
# 25%                0 days 01:00:00
# 50%                0 days 01:57:08
# 75%                0 days 02:04:59
# max                0 days 18:24:54
# Name: Accident_Time, dtype: object
# count                        61157
# mean     0 days 01:57:11.808901679
# std      0 days 01:49:13.790383879
# min                0 days 00:02:30
# 25%                0 days 01:15:01
# 50%                0 days 01:34:00
# 75%                0 days 02:08:46
# max                0 days 23:38:00
# Name: Accident_Time, dtype: object

# %%
df123

# %%
# Check unique values for all cols again
for col in df.columns:
    print(df[col].value_counts(sort=True))
# Out:
# ID
# A-5887205    1
# A-237917     1
# A-5361038    1
# A-4110445    1
# A-1228048    1
#             ..
# A-6985967    1
# A-4223854    1
# A-1495843    1
# A-5332319    1
# A-1337540    1
# Name: count, Length: 28084, dtype: int64
# Source
# Source1    19701
# Source2     8250
# Source3      133
# Name: count, dtype: int64
# Start_Time
# 2021-05-28 07:31:48    9
# 2022-05-31 07:48:30    7
# 2021-08-31 15:40:00    6
# 2022-02-25 15:23:30    6
# 2021-12-24 15:56:30    5
#                       ..
# 2021-04-04 07:24:10    1
# 2023-01-23 06:50:16    1
# 2017-08-23 16:48:45    1
# 2018-04-04 18:57:55    1
# 2023-01-06 04:54:42    1
# Name: count, Length: 26446, dtype: int64
# End_Time
# 2022-08-24 21:05:53    5
# 2022-03-12 16:54:44    4
# 2022-04-14 16:01:28    4
# 2021-11-22 18:45:58    4
# 2021-07-28 19:18:21    4
#                       ..
# 2021-04-04 10:51:38    1
# 2023-01-23 08:09:27    1
# 2017-08-23 22:48:45    1
# 2018-04-05 00:57:55    1
# 2023-01-06 06:14:17    1
# Name: count, Length: 27214, dtype: int64
# Start_Lat
# 38.971164    45
# 39.442020    40
# 39.379276    40
# 39.442108    35
# 39.382286    33
#              ..
# 39.671962     1
# 39.004311     1
# 39.201089     1
# 39.299600     1
# 39.248256     1
# Name: count, Length: 17259, dtype: int64
# Start_Lng
# -77.179063    45
# -76.349358    40
# -76.448280    39
# -76.348763    34
# -76.679230    33
#               ..
# -76.901306     1
# -77.074668     1
# -76.692322     1
# -76.717369     1
# -76.922158     1
# Name: count, Length: 17309, dtype: int64
# End_Lat
# 38.912285    23
# 39.466545    22
# 38.988969    22
# 39.019136    18
# 39.019034    16
#              ..
# 39.329630     1
# 39.405863     1
# 39.382457     1
# 38.980048     1
# 39.145372     1
# Name: count, Length: 13005, dtype: int64
# End_Lng
# -76.934168    23
# -76.987615    22
# -76.286576    22
# -76.959084    18
# -77.388047    16
#               ..
# -75.846650     1
# -76.858240     1
# -76.900852     1
# -75.819471     1
# -76.933413     1
# Name: count, Length: 13042, dtype: int64
# Distance(mi)
# 0.000    7627
# 0.010    1299
# 0.010      76
# 0.020      65
# 0.028      63
#          ...
# 1.540       1
# 0.220       1
# 2.955       1
# 2.045       1
# 2.439       1
# Name: count, Length: 3601, dtype: int64
# Description
# Incident on BRANCH AVE near BRANCH AVE Drive with caution.                                                103
# Incident on CRAIN HWY near CRAIN HWY Drive with caution.                                                   90
# Incident on I-495 WB near I-495 Drive with caution.                                                        85
# Incident on I-495 EB near I-495 Drive with caution.                                                        77
# Incident on INDIAN HEAD HWY near INDIAN HEAD HWY Drive with caution.                                       66
#                                                                                                          ...
# MD 28 EAST/WEST AT PLEASANTVIEW RD                                                                          1
# I-695 OUTER LOOP AT EXIT 15B US 40 BALTO NATIONAL PIKE (OL)                                                 1
# Right lane blocked and right hand shoulder blocked due to accident on I-795 Northbound at McDongh Rd .      1
# Accident on I-495 Capital Beltway anticlockwise at Exits 25B-A 27 I-95.                                     1
# Accident on Terps Blvd at Nittany Lion Cir.                                                                 1
# Name: count, Length: 20390, dtype: int64
# Street
# I-95 S                1171
# I-95 N                1119
# Capital Beltway S      814
# Capital Beltway N      616
# I-695 E                554
#                       ...
# Foxlake Dr               1
# Walnut Ave               1
# Devonshire Ln            1
# Hudson Rd                1
# Piney Orchard Pkwy       1
# Name: count, Length: 3480, dtype: int64
# City
# Baltimore               1910
# Frederick               1625
# Silver Spring           1599
# Hyattsville             1144
# Bethesda                1004
#                         ...
# Great Mills                1
# Kitzmiller                 1
# District 24 Braddock       1
# Rawlings                   1
# District 2                 1
# Name: count, Length: 338, dtype: int64
# County
# Prince George's         5365
# Montgomery              4494
# Baltimore County        3673
# Frederick               2634
# Anne Arundel            2405
# Baltimore City          1761
# Harford                 1349
# Howard                  1169
# Washington               950
# Baltimore                851
# Cecil                    485
# Queen Anne's             409
# Charles                  392
# Baltimore (City)         324
# Carroll                  261
# Worcester                236
# Talbot                   235
# Caroline                 175
# Allegany                 152
# Wicomico                 127
# Dorchester               116
# St. Mary's               111
# Queen Annes               97
# Kent                      70
# Garrett                   69
# Prince Georges            58
# Calvert                   47
# Somerset                  45
# St Marys                  23
# District Of Columbia       1
# Name: count, dtype: int64
# State
# MD    28084
# Name: count, dtype: int64
# Zipcode
# 21227         640
# 21224         631
# 20817         519
# 21704         446
# 21208         428
#              ...
# 20623-1153      1
# 20794-9308      1
# 21561-1437      1
# 21842-3758      1
# 21152-9121      1
# Name: count, Length: 3791, dtype: int64
# Country
# US    28084
# Name: count, dtype: int64
# Timezone
# US/Eastern    28033
# Name: count, dtype: int64
# Airport_Code
# KCGS    4832
# KDMH    4343
# KFDK    2373
# KBWI    2337
# KMTN    1734
# KGAI    1692
# KAPG    1385
# KDCA    1266
# KFME    1219
# KADW    1142
# KWBC     968
# KHGR     729
# KNAK     665
# KDMW     599
# KRSP     402
# KRJD     330
# KW29     297
# KOXB     200
# KESN     197
# KCGE     178
# KILG     171
# KCBE     157
# KDAA     151
# KSBY     150
# K2W6     143
# KMRB     109
# K2G4      64
# KWAL      48
# KJYO      43
# KNHK      32
# KNYG      30
# KRYT      30
# KNUI       3
# Name: count, dtype: int64
# Weather_Timestamp
# 2021-05-28 07:58:00    9
# 2022-03-13 01:55:00    9
# 2022-05-31 07:39:00    8
# 2020-06-04 07:54:00    8
# 2022-01-03 10:47:00    7
#                       ..
# 2022-08-11 21:55:00    1
# 2022-08-23 09:52:00    1
# 2021-04-24 04:56:00    1
# 2018-03-13 07:54:00    1
# 2022-03-21 16:54:00    1
# Name: count, Length: 21261, dtype: int64
# Temperature(F)
# 32.0    540
# 50.0    526
# 45.0    506
# 73.0    502
# 43.0    502
#        ...
# 1.0       1
# 16.9      1
# 60.6      1
# 93.7      1
# 99.0      1
# Name: count, Length: 442, dtype: int64
# Wind_Chill(F)
#  70.0    419
#  72.0    413
#  73.0    408
#  54.0    376
#  50.0    374
#         ...
# -14.5      1
#  1.1       1
#  20.1      1
#  9.9       1
#  5.2       1
# Name: count, Length: 388, dtype: int64
# Humidity(%)
# 100.0    1767
# 93.0     1302
# 94.0     1013
# 87.0      517
# 88.0      436
#          ...
# 11.0        8
# 14.0        7
# 12.0        3
# 10.0        1
# 9.0         1
# Name: count, Length: 92, dtype: int64
# Pressure(in)
# 30.06    439
# 29.94    433
# 30.01    427
# 30.04    418
# 29.99    412
#         ...
# 26.94      1
# 28.82      1
# 27.15      1
# 26.75      1
# 28.76      1
# Name: count, Length: 236, dtype: int64
# Visibility(mi)
# 10.00    17732
# 7.00      1134
# 5.00       557
# 3.00       460
# 4.00       455
# 2.00       408
# 1.00       391
# 9.00       357
# 8.00       260
# 6.00       258
# 0.50       114
# 0.25        89
# 2.50        69
# 0.75        56
# 0.20        38
# 1.50        35
# 1.80        27
# 0.80        21
# 1.20        17
# 0.12         9
# 0.00         9
# 0.38         7
# 0.19         7
# 0.10         4
# 0.63         4
# 0.06         2
# 20.00        2
# 2.80         1
# 0.60         1
# 0.88         1
# 1.90         1
# 10.50        1
# Name: count, dtype: int64
# Wind_Direction
# CALM        4497
# WNW         1639
# NW          1576
# North       1573
# Calm        1494
# W           1298
# S           1240
# NNW         1120
# SSW         1070
# N            915
# SW           870
# SSE          766
# SE           748
# NNE          734
# WSW          726
# NE           641
# ENE          578
# E            568
# ESE          484
# West         402
# VAR          397
# South        291
# East         223
# Variable     155
# Name: count, dtype: int64
# Wind_Speed(mph)
# 0.0      4497
# 6.0      1792
# 5.0      1761
# 3.0      1730
# 7.0      1546
# 8.0      1192
# 9.0      1101
# 10.0      918
# 12.0      743
# 3.5       573
# 13.0      522
# 5.8       512
# 4.6       511
# 6.9       449
# 14.0      411
# 15.0      405
# 8.1       345
# 9.2       293
# 10.4      264
# 11.5      216
# 16.0      207
# 17.0      166
# 12.7      126
# 13.8      126
# 18.0      118
# 20.0       99
# 17.3       80
# 21.0       71
# 16.1       69
# 23.0       50
# 18.4       43
# 22.0       40
# 19.6       35
# 20.7       22
# 21.9       21
# 24.0       20
# 25.0       19
# 24.2        9
# 25.3        8
# 2.3         5
# 29.0        5
# 26.5        5
# 30.0        5
# 26.0        5
# 31.0        4
# 28.8        4
# 28.0        3
# 32.0        3
# 38.0        3
# 27.6        2
# 32.2        1
# 31.1        1
# 126.6       1
# 33.0        1
# 33.4        1
# 1.0         1
# Name: count, dtype: int64
# Precipitation(in)
# 0.00    16772
# 0.01      388
# 0.02      220
# 0.03      136
# 0.04      100
#         ...
# 1.37        1
# 0.49        1
# 0.83        1
# 0.40        1
# 0.61        1
# Name: count, Length: 61, dtype: int64
# Weather_Condition
# Fair                    7770
# Cloudy                  3608
# Mostly Cloudy           2886
# Partly Cloudy           1938
# Clear                   1898
#                         ...
# Light Freezing Fog         2
# Sand                       1
# Light Sleet / Windy        1
# Light Snow and Sleet       1
# Wintry Mix / Windy         1
# Name: count, Length: 61, dtype: int64
# Amenity
# False    27887
# True       197
# Name: count, dtype: int64
# Bump
# False    28080
# True         4
# Name: count, dtype: int64
# Crossing
# False    26272
# True      1812
# Name: count, dtype: int64
# Give_Way
# False    28009
# True        75
# Name: count, dtype: int64
# Junction
# False    24638
# True      3446
# Name: count, dtype: int64
# No_Exit
# False    28045
# True        39
# Name: count, dtype: int64
# Railway
# False    27966
# True       118
# Name: count, dtype: int64
# Roundabout
# False    28083
# True         1
# Name: count, dtype: int64
# Station
# False    27579
# True       505
# Name: count, dtype: int64
# Stop
# False    27789
# True       295
# Name: count, dtype: int64
# Traffic_Calming
# False    27980
# True       104
# Name: count, dtype: int64
# Traffic_Signal
# False    24880
# True      3204
# Name: count, dtype: int64
# Turning_Loop
# False    28084
# Name: count, dtype: int64
# Sunrise_Sunset
# Day      18715
# Night     9315
# Name: count, dtype: int64
# Civil_Twilight
# Day      20084
# Night     7946
# Name: count, dtype: int64
# Nautical_Twilight
# Day      21476
# Night     6554
# Name: count, dtype: int64
# Astronomical_Twilight
# Day      22676
# Night     5354
# Name: count, dtype: int64
# Severity
# 2    20712
# 3     5090
# 4     2179
# 1      103
# Name: count, dtype: int64

# %%
# Create month column out of date time
df['Month'] = df['Start_Time'].dt.month
df['Accident_Time']
df
# Out:
#               ID   Source          Start_Time            End_Time  Start_Lat  \
# 0       A-237917  Source2 2016-10-23 08:04:38 2016-10-23 09:04:14  39.011890
# 1      A-5361038  Source1 2022-03-10 17:06:30 2022-03-10 17:28:30  38.599807
# 2      A-4110445  Source1 2022-09-19 04:45:21 2022-09-19 06:01:06  38.930465
# 3      A-1228048  Source2 2020-12-15 08:03:36 2020-12-15 09:18:22  39.562180
# 4      A-1450465  Source2 2020-05-28 08:21:25 2020-05-28 09:05:57  39.277962
# ...          ...      ...                 ...                 ...        ...
# 28079  A-7005722  Source1 2020-05-01 15:02:13 2020-05-01 16:22:11  39.378680
# 28080  A-3468597  Source1 2016-11-08 17:55:16 2016-11-08 23:55:16  39.352120
# 28081  A-6590777  Source1 2020-10-25 05:01:51 2020-10-25 07:21:33  39.158078
# 28082  A-6480985  Source1 2021-02-04 14:41:00 2021-02-04 16:56:10  39.097107
# 28083  A-5887205  Source1 2021-06-23 23:39:31 2021-06-24 01:00:23  38.852312
#
#        Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0     -76.904198        NaN        NaN         0.010
# 1     -75.913079  38.606758 -75.902799         0.734
# 2     -76.013555  38.931595 -76.019579         0.333
# 3     -76.361221        NaN        NaN         0.000
# 4     -77.323425        NaN        NaN         0.000
# ...          ...        ...        ...           ...
# 28079 -76.718500  39.378680 -76.718500         0.000
# 28080 -76.745910  39.345290 -76.745300         0.473
# 28081 -77.204488  39.157831 -77.204819         0.025
# 28082 -77.177733  39.051836 -77.152782         3.402
# 28083 -76.914312  38.852249 -76.915004         0.037
#
#                                              Description  ...   Stop  \
# 0      Accident on I-95 Capital Beltway Southbound at...  ...  False
# 1      Stationary traffic on MD-392 from MD-14/E New ...  ...  False
# 2      Incident on MD-404 WB near DULIN RD Drive with...  ...  False
# 3                Accident on Kahoe Rd at Bynum Ridge Rd.  ...  False
# 4      Accident on I-270 Northbound before Exit 22 MD...  ...  False
# ...                                                  ...  ...    ...
# 28079                       At E Sudbrook Ln - Accident.  ...  False
# 28080                       At MD-26/Exit 18 - Accident.  ...  False
# 28081  Incident on MD-124 SB near LOST KNIFE RD Road ...  ...  False
# 28082  Incident on I-270 SB near I-370 Road closed. T...  ...  False
# 28083  Incident on MD-458 WB near PLAZA DR Road close...  ...  False
#
#       Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0               False          False        False            Day
# 1               False          False        False            Day
# 2               False          False        False          Night
# 3               False          False        False            Day
# 4               False          False        False            Day
# ...               ...            ...          ...            ...
# 28079           False           True        False            Day
# 28080           False          False        False          Night
# 28081           False           True        False          Night
# 28082           False          False        False            Day
# 28083           False          False        False          Night
#
#       Civil_Twilight Nautical_Twilight Astronomical_Twilight Severity  Month
# 0                Day               Day                   Day        3     10
# 1                Day               Day                   Day        2      3
# 2              Night             Night                 Night        2      9
# 3                Day               Day                   Day        2     12
# 4                Day               Day                   Day        2      5
# ...              ...               ...                   ...      ...    ...
# 28079            Day               Day                   Day        2      5
# 28080          Night               Day                   Day        3     11
# 28081          Night             Night                 Night        4     10
# 28082            Day               Day                   Day        2      2
# 28083          Night             Night                 Night        4      6
#
# [28084 rows x 47 columns]

# %%
# Use month column to create season column:
# Dec/Jan/Feb: Winter
# Mar/Apr/May: Spring
# Jun/Jul/Aug: Summer
# Sep/Oct/Nov: Fall
def season(x):
    tomap = {1:"Winter",2:"Winter",3:"Spring",4:"Spring",5:"Spring",6:"Summer",7:"Summer",8:"Summer",9:"Fall",10:"Fall",11:"Fall",12:"Winter"}
    if x in tomap:
        return tomap[x]
    return x

# %%
# Pandas giving data issues, confirmation that month is created and datetime
df['Start_Time'] = pd.to_datetime(df['Start_Time'],format='mixed')
df['Month'] = df['Start_Time'].dt.month

# Apply season function based on month col
df["Season"] = df.Month.apply(season)
df['Season'].value_counts()
# Out:
# Season
# Winter    8068
# Fall      7576
# Summer    6254
# Spring    6186
# Name: count, dtype: int64

# %%
df = df[~df.Street.str.contains("Francis Scott Key Bridge",na=False)|~df.Street.str.contains("Alexandria - Gaylord",na=False)]
# Convert street names to strings
df['Street']=df['Street'].astype(str)

# %%
def street_type(x):
    if "Tunl" in x or "Tunnel" in x:
        return "Tunnel"#nsew(x,"Tunnel")
    if "I-" in x or "I " in x:
        return "Interstate"
    if " Dr " in x or " Ave " in x or " Rd " in x or " Xing" in x or " Way " in x:
        return "local"
    if "Beltway" in x:
        return "Beltway"
    if "US-" in x[:4] or "US " in x or "MD-" in x[:4] or "Expy" in x:
        return "Highway"
    if "Hwy" in x or "Fwy" in x or "Highway" in x or "Route" in x or "Connector" in x or "Byp" in x \
        or "Bypass" in x or "Gtwy" in x or "Brg" in x or "Trwy" in x or "Rt" in x or "Conn" in x or "Exp" in x \
        or "Thwy" in x:
        return "Highway"
    if x[-2:] in ["St","Pl","Dr","Sq"]:
        return "local"
    if "Ln" in x or "Rd" in x or "Ct" in x:
        return "local"
    if x[-3:] in ["Way","Cir","Ter","Trl","Plz","Aly","Grn","way","Ext"]:
        return "local"
    if x[-3:] in ["-A", "-B", "-11", "-33"]:
        return "on_off_ramp"
    if x[-1] in ["A", "B", "C"]:
        return "on_off_ramp"
    if "Ave" in x[-5:] or " Blvd" in x or " Pike" in x or "Pkwy" in x or "Crse" in x or "Alameda" in x:
        return "large_local"
    if "Garth" in x or "Spell" in x or "Psge" in x or "Chase" in x or "Cutoff" in x or "Spire" in x:
        return "local"
    if "Overlook" in x or "Battlefield" in x or "Cemetery" in x or "Park" in x or "Base" in x or "Concourse" in x \
        or "Memorial" in x or "Booth's" in x or "Bywy" in x or "Underground" in x:
        return "special"
    if "Loop" in x or "Greenway" in x or "West" in x or "ville" in x or "wood" in x:
        return "local"
    if "St" in x or "Mnr" in x or "Pass" in x or "Run" in x or "Mall" in x or "Row" in x or "Grv":
        return "local"
    return x

# %%
# Apply street categories to street name col
df["Street"] = df.Street.apply(street_type)

# %%
df.Street.value_counts()
# Out:
# Street
# Interstate     7812
# local          6902
# Highway        5149
# large_local    4864
# Beltway        2832
# Tunnel          410
# on_off_ramp      89
# special          26
# Name: count, dtype: int64

# %%
# Remove rows with "special" or "misc" street names
df=df.loc[~df.Street.str.contains("special")]

# %%
df.Street.value_counts()
# Out:
# Street
# Interstate     7812
# local          6902
# Highway        5149
# large_local    4864
# Beltway        2832
# Tunnel          410
# on_off_ramp      89
# Name: count, dtype: int64

# %%
# Proper formatting of county names (I took an educated guess that \"Baltimore\" referred to Balt. County and not City, this
# may not be correct)
# Also apostrophes needed to be removed to work with Weka for binning after cleaning data

def replace_misspelled(text):
    corrections = {"St Mary's": "St. Marys", "Prince George's": "Prince Georges", "Queen Anne's": "Queen Annes",
                   "Baltimore (City)":"Baltimore City","Saint Mary's":"St Marys", "Baltimore County":"Baltimore",
                   "St. Mary's":"St Marys", "Saint Marys":"St Marys"}
    for word, correction in corrections.items():
        text = text.replace(word, correction)
    return text

# Apply spelling function to data
#df.loc[:,'County'] = df['County'].apply(replace_misspelled)
#df["County"].value_counts(sort=True)

# %%
# One hot function (Could not find the one line function Dr. Olsen referred to)
def onehotinator(df, string):
    one_hot = pd.get_dummies(df[string], prefix=string)
    one_hot = one_hot.astype(int)
    df = df.join(one_hot)
    df = df.drop(columns=string)
    return df

# %%
# Boolean column feature for if snowy OR icy conditions were present
# Tried to fix the warning about setting value to a DF slice, was not able to fix
lst = ['Snow', 'Freezing', 'Ice', 'Wintry', 'Hail', 'Sleet']
df['Snow_Ice']=np.where(df.loc[:, 'Weather_Condition'].str.contains('|'.join(lst), na=False), True, False)

# %%
# Boolean column feature for if mist OR fog OR haze was present, OR if visibility in miles was less than 0.001 mi
lst = ['Fog', 'Mist', 'Haze', 'Heavy']
df['Low_Vis_Weather']=np.where((df['Weather_Condition'].str.contains('|'.join(lst), na=False) | df["Visibility(mi)"] < 0.001), True, False)

# %%
# Boolean column feature for if road conditions were wet (weather was rain/storm related, OR there was more than 0 inches
# of precipitation at time of crash)
lst = ['Rain', 'Drizzle', 'Thunderstorm', 'T-Storm', 'Precipitation']
df['Rainy']=np.where((df['Weather_Condition'].str.contains('|'.join(lst), na=False) | df['Precipitation(in)'] >= 0.01), True, False)

# %%
# Check which columns to delete
df
# Out:
#               ID   Source          Start_Time            End_Time  Start_Lat  \
# 0       A-237917  Source2 2016-10-23 08:04:38 2016-10-23 09:04:14  39.011890
# 1      A-5361038  Source1 2022-03-10 17:06:30 2022-03-10 17:28:30  38.599807
# 2      A-4110445  Source1 2022-09-19 04:45:21 2022-09-19 06:01:06  38.930465
# 3      A-1228048  Source2 2020-12-15 08:03:36 2020-12-15 09:18:22  39.562180
# 4      A-1450465  Source2 2020-05-28 08:21:25 2020-05-28 09:05:57  39.277962
# ...          ...      ...                 ...                 ...        ...
# 28079  A-7005722  Source1 2020-05-01 15:02:13 2020-05-01 16:22:11  39.378680
# 28080  A-3468597  Source1 2016-11-08 17:55:16 2016-11-08 23:55:16  39.352120
# 28081  A-6590777  Source1 2020-10-25 05:01:51 2020-10-25 07:21:33  39.158078
# 28082  A-6480985  Source1 2021-02-04 14:41:00 2021-02-04 16:56:10  39.097107
# 28083  A-5887205  Source1 2021-06-23 23:39:31 2021-06-24 01:00:23  38.852312
#
#        Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0     -76.904198        NaN        NaN         0.010
# 1     -75.913079  38.606758 -75.902799         0.734
# 2     -76.013555  38.931595 -76.019579         0.333
# 3     -76.361221        NaN        NaN         0.000
# 4     -77.323425        NaN        NaN         0.000
# ...          ...        ...        ...           ...
# 28079 -76.718500  39.378680 -76.718500         0.000
# 28080 -76.745910  39.345290 -76.745300         0.473
# 28081 -77.204488  39.157831 -77.204819         0.025
# 28082 -77.177733  39.051836 -77.152782         3.402
# 28083 -76.914312  38.852249 -76.915004         0.037
#
#                                              Description  ... Sunrise_Sunset  \
# 0      Accident on I-95 Capital Beltway Southbound at...  ...            Day
# 1      Stationary traffic on MD-392 from MD-14/E New ...  ...            Day
# 2      Incident on MD-404 WB near DULIN RD Drive with...  ...          Night
# 3                Accident on Kahoe Rd at Bynum Ridge Rd.  ...            Day
# 4      Accident on I-270 Northbound before Exit 22 MD...  ...            Day
# ...                                                  ...  ...            ...
# 28079                       At E Sudbrook Ln - Accident.  ...            Day
# 28080                       At MD-26/Exit 18 - Accident.  ...          Night
# 28081  Incident on MD-124 SB near LOST KNIFE RD Road ...  ...          Night
# 28082  Incident on I-270 SB near I-370 Road closed. T...  ...            Day
# 28083  Incident on MD-458 WB near PLAZA DR Road close...  ...          Night
#
#       Civil_Twilight Nautical_Twilight Astronomical_Twilight Severity Month  \
# 0                Day               Day                   Day        3    10
# 1                Day               Day                   Day        2     3
# 2              Night             Night                 Night        2     9
# 3                Day               Day                   Day        2    12
# 4                Day               Day                   Day        2     5
# ...              ...               ...                   ...      ...   ...
# 28079            Day               Day                   Day        2     5
# 28080          Night               Day                   Day        3    11
# 28081          Night             Night                 Night        4    10
# 28082            Day               Day                   Day        2     2
# 28083          Night             Night                 Night        4     6
#
#        Season Snow_Ice Low_Vis_Weather  Rainy
# 0        Fall    False           False  False
# 1      Spring    False           False  False
# 2        Fall    False           False  False
# 3      Winter    False           False  False
# 4      Spring    False           False   True
# ...       ...      ...             ...    ...
# 28079  Spring    False            True  False
# 28080    Fall    False            True  False
# 28081    Fall    False           False  False
# 28082  Winter    False           False  False
# 28083  Summer    False           False  False
#
# [28058 rows x 51 columns]

# %%
# Remove all but one day/night column

df = df.drop(columns=['Civil_Twilight', 'Nautical_Twilight', 'Astronomical_Twilight', 'Weather_Condition'])


df['Sunrise_Sunset'] = df['Sunrise_Sunset'].astype("string")

#df = df.dropna(subset = ['Sunrise_Sunset'], axis = 0)
df['Sunrise_Sunset'].value_counts()
# Out:
# Sunrise_Sunset
# Day      18696
# Night     9308
# Name: count, dtype: Int64

# %%
# Reference for data conversion
df.dtypes
# Out:
# ID                           object
# Source                       object
# Start_Time           datetime64[ns]
# End_Time             datetime64[ns]
# Start_Lat                   float64
# Start_Lng                   float64
# End_Lat                     float64
# End_Lng                     float64
# Distance(mi)                float64
# Description                  object
# Street                       object
# City                         object
# County                       object
# State                        object
# Zipcode                      object
# Country                      object
# Timezone                     object
# Airport_Code                 object
# Weather_Timestamp            object
# Temperature(F)              float64
# Wind_Chill(F)               float64
# Humidity(%)                 float64
# Pressure(in)                float64
# Visibility(mi)              float64
# Wind_Direction               object
# Wind_Speed(mph)             float64
# Precipitation(in)           float64
# Amenity                        bool
# Bump                           bool
# Crossing                       bool
# Give_Way                       bool
# Junction                       bool
# No_Exit                        bool
# Railway                        bool
# Roundabout                     bool
# Station                        bool
# Stop                           bool
# Traffic_Calming                bool
# Traffic_Signal                 bool
# Turning_Loop                   bool
# Sunrise_Sunset       string[python]
# Severity                      int64
# Month                         int32
# Season                       object
# Snow_Ice                       bool
# Low_Vis_Weather                bool
# Rainy                          bool
# dtype: object

# %%
# Convert all boolean columns to 1/0 integer columns and day/night column to 1/0

bools = ['Amenity', 'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 
         'Traffic_Signal', 'Turning_Loop', 'Low_Vis_Weather', 'Snow_Ice', 'Rainy']

for i in bools:
    df = df.astype({i:int})
df['Sunrise_Sunset'] = df["Sunrise_Sunset"].map({'Day':1,'Night':0})
df.dtypes
# Out:
# ID                           object
# Source                       object
# Start_Time           datetime64[ns]
# End_Time             datetime64[ns]
# Start_Lat                   float64
# Start_Lng                   float64
# End_Lat                     float64
# End_Lng                     float64
# Distance(mi)                float64
# Description                  object
# Street                       object
# City                         object
# County                       object
# State                        object
# Zipcode                      object
# Country                      object
# Timezone                     object
# Airport_Code                 object
# Weather_Timestamp            object
# Temperature(F)              float64
# Wind_Chill(F)               float64
# Humidity(%)                 float64
# Pressure(in)                float64
# Visibility(mi)              float64
# Wind_Direction               object
# Wind_Speed(mph)             float64
# Precipitation(in)           float64
# Amenity                       int64
# Bump                          int64
# Crossing                      int64
# Give_Way                      int64
# Junction                      int64
# No_Exit                       int64
# Railway                       int64
# Roundabout                    int64
# Station                       int64
# Stop                          int64
# Traffic_Calming               int64
# Traffic_Signal                int64
# Turning_Loop                  int64
# Sunrise_Sunset              float64
# Severity                      int64
# Month                         int32
# Season                       object
# Snow_Ice                      int64
# Low_Vis_Weather               int64
# Rainy                         int64
# dtype: object

# %%
# Function to tally number of traffic speed changing elements present at location of accident
def slowdown_level(row):
    return sum([row['Bump'],row["Crossing"], row["Give_Way"], row["Junction"], row["Railway"], row['Roundabout'], \
                row["Stop"], row["Traffic_Calming"], row["Traffic_Signal"], row["Turning_Loop"]])

df['Qty_Slowing_Elements'] = df.apply(slowdown_level, axis=1)

df['Qty_Slowing_Elements'].value_counts()
df = df.drop(columns=['Bump', 'Crossing', 'Give_Way', 'Junction', 'Railway', 'Roundabout', 'Stop', 'Traffic_Calming',
                      'Traffic_Signal', 'Turning_Loop'])

# %%
df.head()
# Out:
#           ID   Source          Start_Time            End_Time  Start_Lat  \
# 0   A-237917  Source2 2016-10-23 08:04:38 2016-10-23 09:04:14  39.011890
# 1  A-5361038  Source1 2022-03-10 17:06:30 2022-03-10 17:28:30  38.599807
# 2  A-4110445  Source1 2022-09-19 04:45:21 2022-09-19 06:01:06  38.930465
# 3  A-1228048  Source2 2020-12-15 08:03:36 2020-12-15 09:18:22  39.562180
# 4  A-1450465  Source2 2020-05-28 08:21:25 2020-05-28 09:05:57  39.277962
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -76.904198        NaN        NaN         0.010
# 1 -75.913079  38.606758 -75.902799         0.734
# 2 -76.013555  38.931595 -76.019579         0.333
# 3 -76.361221        NaN        NaN         0.000
# 4 -77.323425        NaN        NaN         0.000
#
#                                          Description  ... No_Exit Station  \
# 0  Accident on I-95 Capital Beltway Southbound at...  ...       0       0
# 1  Stationary traffic on MD-392 from MD-14/E New ...  ...       0       0
# 2  Incident on MD-404 WB near DULIN RD Drive with...  ...       0       0
# 3            Accident on Kahoe Rd at Bynum Ridge Rd.  ...       0       0
# 4  Accident on I-270 Northbound before Exit 22 MD...  ...       0       0
#
#   Sunrise_Sunset Severity Month  Season Snow_Ice Low_Vis_Weather Rainy  \
# 0            1.0        3    10    Fall        0               0     0
# 1            1.0        2     3  Spring        0               0     0
# 2            0.0        2     9    Fall        0               0     0
# 3            1.0        2    12  Winter        0               0     0
# 4            1.0        2     5  Spring        0               0     1
#
#    Qty_Slowing_Elements
# 0                     0
# 1                     2
# 2                     0
# 3                     0
# 4                     1
#
# [5 rows x 38 columns]

# %%
# Reference for what to do next
df.isnull().sum()
# Out:
# ID                         0
# Source                     0
# Start_Time                 0
# End_Time                   0
# Start_Lat                  0
# Start_Lng                  0
# End_Lat                 8380
# End_Lng                 8380
# Distance(mi)               0
# Description                0
# Street                     0
# City                       1
# County                     0
# State                      0
# Zipcode                   51
# Country                    0
# Timezone                  51
# Airport_Code              65
# Weather_Timestamp       2741
# Temperature(F)          3166
# Wind_Chill(F)           9581
# Humidity(%)             3192
# Pressure(in)            2944
# Visibility(mi)          5555
# Wind_Direction          4078
# Wind_Speed(mph)         6922
# Precipitation(in)       9887
# Amenity                    0
# No_Exit                    0
# Station                    0
# Sunrise_Sunset            54
# Severity                   0
# Month                      0
# Season                     0
# Snow_Ice                   0
# Low_Vis_Weather            0
# Rainy                      0
# Qty_Slowing_Elements       0
# dtype: int64

# %%
# Due to a technical ctrl+z error, I lost all instances of removing columns as I went, this is a quick fix (I didn't remember
# which columns were removed at which points)
df = df.drop(columns=['ID','Source','Start_Time','End_Time','Start_Lat','Start_Lng','End_Lat','End_Lng','Weather_Timestamp',
                      'Temperature(F)','Wind_Chill(F)','Humidity(%)','Pressure(in)','Visibility(mi)','Wind_Direction',
                      'Wind_Speed(mph)','Precipitation(in)','Description','Street','City','State','Zipcode','Country','Timezone',
                      'Airport_Code','Month'])

# Dropping remaining null values left

df.isnull().sum()
df
# Out:
#        Distance(mi)            County  Amenity  No_Exit  Station  \
# 0             0.010   Prince George's        0        0        0
# 1             0.734        Dorchester        0        0        0
# 2             0.333            Talbot        0        0        0
# 3             0.000           Harford        0        0        0
# 4             0.000        Montgomery        0        0        0
# ...             ...               ...      ...      ...      ...
# 28079         0.000  Baltimore County        0        0        0
# 28080         0.473  Baltimore County        0        0        0
# 28081         0.025        Montgomery        0        0        0
# 28082         3.402        Montgomery        0        0        0
# 28083         0.037   Prince George's        0        0        0
#
#        Sunrise_Sunset  Severity  Season  Snow_Ice  Low_Vis_Weather  Rainy  \
# 0                 1.0         3    Fall         0                0      0
# 1                 1.0         2  Spring         0                0      0
# 2                 0.0         2    Fall         0                0      0
# 3                 1.0         2  Winter         0                0      0
# 4                 1.0         2  Spring         0                0      1
# ...               ...       ...     ...       ...              ...    ...
# 28079             1.0         2  Spring         0                1      0
# 28080             0.0         3    Fall         0                1      0
# 28081             0.0         4    Fall         0                0      0
# 28082             1.0         2  Winter         0                0      0
# 28083             0.0         4  Summer         0                0      0
#
#        Qty_Slowing_Elements
# 0                         0
# 1                         2
# 2                         0
# 3                         0
# 4                         1
# ...                     ...
# 28079                     1
# 28080                     0
# 28081                     1
# 28082                     0
# 28083                     0
#
# [28058 rows x 12 columns]

# %%
df = df.dropna(how='any')

# %%
df.dtypes

# Somehow sun up/down col was a float, quick fix to be int
df.Sunrise_Sunset = df.Sunrise_Sunset.astype('int64')
df.dtypes
# Out:
# C:\Users\bkb3\AppData\Local\Temp\ipykernel_15456\1210191251.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Sunrise_Sunset = df.Sunrise_Sunset.astype('int64')
# Distance(mi)            float64
# County                   object
# Amenity                   int64
# No_Exit                   int64
# Station                   int64
# Sunrise_Sunset            int64
# Severity                  int64
# Season                   object
# Snow_Ice                  int64
# Low_Vis_Weather           int64
# Rainy                     int64
# Qty_Slowing_Elements      int64
# dtype: object

# %%
df=df.drop_duplicates()

# %%
# Reference for thinking about CFD based division (We have 4 classes, and CFD only takes 2 at a time)
df['Severity'].value_counts()
# Out:
# Severity
# 2    15141
# 4     2063
# 3     1782
# 1       70
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Distance(mi)', 'County', 'Amenity', 'No_Exit', 'Station',
#        'Sunrise_Sunset', 'Severity', 'Season', 'Snow_Ice', 'Low_Vis_Weather',
#        'Rainy', 'Qty_Slowing_Elements'],
#       dtype='object')

# %%
df.shape
# Out:
# (19056, 12)

# %%
# Function to re-separate cleaned class column from the cleaned rest of the dataset, and export both separately into the same folder
def data_output(df, folder1, folder2, file_x, file_y):
    col_class = ['Class']
    col_data = ['Distance(mi)', 'Amenity', 'No_Exit', 'Station', 'Sunrise_Sunset',
       'Season', 'Snow_Ice', 'Low_Vis_Weather', 'Rainy',
       'Qty_Slowing_Elements']
    
    df = df.rename(columns = {'Severity' : 'Class'})
    df = df.drop_duplicates()
    
    X = df.loc[:, df.columns != 'Class']
    y = df.Class
    
    X.to_csv(f'../Accident_Data_Preprocessing/{folder1}/{folder2}/{file_x}.csv', columns = col_data, index = False)
    y.to_csv(f'../Accident_Data_Preprocessing/{folder1}/{folder2}/{file_y}.csv', columns = col_class, index = False)

# %%
# TRAIN OUTPUT
#data_output(df, "Data_Cleaned", "train_data", "X_train_feat_eng", "y_train_feat_eng")

# %%
# TEST OUTPUT
data_output(df, "Data_Cleaned", "test_data", "X_test_feat_eng", "y_test_feat_eng")
